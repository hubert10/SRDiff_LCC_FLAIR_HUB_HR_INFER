# %%
# Add Importing files from different parallel folder
import sys
import yaml
import os
from pathlib import Path

module_path = str(Path.cwd().parents[0])
if module_path not in sys.path:
    sys.path.append(module_path)

# sys.path.append(
#     "./"
# )  # https://stackoverflow.com/questions/4383571/importing-files-from-different-folder

from pathlib import Path
from src.data_display import display_predictions, get_data_paths
from src.load_data import load_data


config_path = "../flair-2-config.yml"  # Change to yours
with open(config_path, "r") as f:
    config = yaml.safe_load(f)

# Creation of the train, val and test dictionnaries with the data file paths
d_train, d_val, d_test = load_data(config)

images = d_train["PATH_IMG"]

out_dir = Path(config["outputs"]["out_folder"], config["outputs"]["out_model_name"])

print(os.path.join(out_dir, "predictions" + "_" + config["outputs"]["out_model_name"]))
print(
    list(
        get_data_paths(
            Path(
                os.path.join(
                    out_dir, "predictions" + "_" + config["outputs"]["out_model_name"]
                )
            ),
            "PRED*.tif",
        )
    )
)

images_test = d_test["PATH_IMG"]
predictions = sorted(
    list(
        get_data_paths(
            Path(
                os.path.join(
                    out_dir, "predictions" + "_" + config["outputs"]["out_model_name"]
                )
            ),
            "PRED*.tif",
        )
    )
)

print("Predictions", predictions)
print("images_test", images_test)

display_predictions(images_test, predictions, nb_samples=1)
# CMD: python ./visualizations/display_predictions.py
# Out:
# Results\flair-two-toy-baseline\predictions_flair-two-toy-baseline
# []
# Predictions []
# images_test ['C:/Users/kanyamahanga/Desktop/IPI-128/RESEARCH/Experiments/FLAIR-3-AI-Challenge/data/flair_2_toy_aerial_test/D008_2019/Z13_UA/img/IMG_006512.tif', 'C:/Users/kanyamahanga/Desktop/IPI-128/RESEARCH/Experiments/FLAIR-3-AI-Challenge/data/flair_2_toy_aerial_test/D008_2019/Z17_UA/img/IMG_006975.tif', 'C:/Users/kanyamahanga/Desktop/IPI-128/RESEARCH/Experiments/FLAIR-3-AI-Challenge/data/flair_2_toy_aerial_test/D029_2021/Z1_UA/img/IMG_017541.tif', 'C:/Users/kanyamahanga/Desktop/IPI-128/RESEARCH/Experiments/FLAIR-3-AI-Challenge/data/flair_2_toy_aerial_test/D033_2021/Z12_NF/img/IMG_024295.tif', 'C:/Users/kanyamahanga/Desktop/IPI-128/RESEARCH/Experiments/FLAIR-3-AI-Challenge/data/flair_2_toy_aerial_test/D033_2021/Z20_UN/img/IMG_024977.tif', 'C:/Users/kanyamahanga/Desktop/IPI-128/RESEARCH/Experiments/FLAIR-3-AI-Challenge/data/flair_2_toy_aerial_test/D033_2021/Z3_UA/img/IMG_023660.tif', 'C:/Users/kanyamahanga/Desktop/IPI-128/RESEARCH/Experiments/FLAIR-3-AI-Challenge/data/flair_2_toy_aerial_test/D033_2021/Z5_UU/img/IMG_023754.tif', 'C:/Users/kanyamahanga/Desktop/IPI-128/RESEARCH/Experiments/FLAIR-3-AI-Challenge/data/flair_2_toy_aerial_test/D044_2020/Z24_UU/img/IMG_028617.tif', 'C:/Users/kanyamahanga/Desktop/IPI-128/RESEARCH/Experiments/FLAIR-3-AI-Challenge/data/flair_2_toy_aerial_test/D044_2020/Z25_UU/img/IMG_028645.tif', 'C:/Users/kanyamahanga/Desktop/IPI-128/RESEARCH/Experiments/FLAIR-3-AI-Challenge/data/flair_2_toy_aerial_test/D067_2021/Z1_AU/img/IMG_045182.tif', 'C:/Users/kanyamahanga/Desktop/IPI-128/RESEARCH/Experiments/FLAIR-3-AI-Challenge/data/flair_2_toy_aerial_test/D067_2021/Z3_UA/img/IMG_045405.tif', 'C:/Users/kanyamahanga/Desktop/IPI-128/RESEARCH/Experiments/FLAIR-3-AI-Challenge/data/flair_2_toy_aerial_test/D067_2021/Z9_UN/img/IMG_046046.tif']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 40
#      37 print('Predictions', predictions)
#      38 print('images_test', images_test)
# ---> 40 display_predictions(images_test, predictions, nb_samples=1)
#
# File ~\Desktop\IPI-128\RESEARCH\Experiments\FLAIR-3-AI-Challenge\src\data_display.py:344, in display_predictions(images, predictions, nb_samples, palette, classes)
#     341 def display_predictions(
#     342     images, predictions, nb_samples: int, palette=lut_colors, classes=lut_classes
#     343 ) -> None:
# --> 344     indices = random.sample(range(0, len(predictions)), nb_samples)
#     345     fig, axs = plt.subplots(nrows=nb_samples, ncols=2, figsize=(17, nb_samples * 8))
#     346     fig.subplots_adjust(wspace=0.0, hspace=0.01)
#
# File ~\anaconda3\envs\pyt_1_11\lib\random.py:482, in Random.sample(self, population, k, counts)
#     480 randbelow = self._randbelow
#     481 if not 0 <= k <= n:
# --> 482     raise ValueError("Sample larger than population or is negative")
#     483 result = [None] * k
#     484 setsize = 21        # size of a small set minus size of an empty list
#
# ValueError: Sample larger than population or is negative
